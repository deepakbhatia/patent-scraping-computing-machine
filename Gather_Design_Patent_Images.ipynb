# %%
from lxml import html
import requests
url = 'https://bulkdata.uspto.gov/data/patent/officialgazette/2007/'
page = requests.get(url)
content = html.fromstring(page.content)
tr_elements = content.xpath('//tr')

# %%
# !mkdir gazettes
# !mkdir gazette_zips

# %%
import urllib.request
import zipfile
import os

table_data = []
for column in tr_elements:
  name = column.text_content()
  table_data.append((name, []))

for row in range(1, len(tr_elements)):
  table_tr = tr_elements[row]
  column_count = 0

  for column in table_tr.iterchildren():
    data = column.text_content()
    table_data[column_count][1].append(data)
    column_count += 1

dictionary = {title : column for (title, column) in table_data}

for file_name in dictionary['FILENAMESIZE (bytes)DATE/TIME'][:1]:
  full_url = url + file_name
  print(file_name)
  urllib.request.urlretrieve(full_url, os.path.join("gazette_zips", file_name))
  with zipfile.ZipFile(os.path.join("gazette_zips", file_name), 'r') as zip_ref:
    zip_ref.extractall("gazettes")

# %%
import glob 
html_files = sorted(glob.glob('gazettes/**/OG/html/**/USD*.html',  recursive = True))
print(len(html_files))
print(html_files[:5])
# Out:
# 375
# ['gazettes/1314-1/OG/html/1314-1/USD0534331-20070102.html', 'gazettes/1314-1/OG/html/1314-1/USD0534332-20070102.html', 'gazettes/1314-1/OG/html/1314-1/USD0534333-20070102.html', 'gazettes/1314-1/OG/html/1314-1/USD0534334-20070102.html', 'gazettes/1314-1/OG/html/1314-1/USD0534335-20070102.html']

# %%
# !mkdir design_patent_images_2007

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import numpy as np

target_size = 512 # 224
metadata_file = open("metadata_2007.txt", 'w')

for file_name in html_files:
  # print(file_name)
  with open(file_name,"r") as f:
    web_page = f.read()
    text_head = 'uppercase"><b>'
    text_start = web_page.find(text_head)
    if text_start is not -1:
      text_tail = '</b>'
      text_end = web_page.find(text_tail, text_start + len(text_head))
      if text_end is not -1:
        title = web_page[text_start + len(text_head):text_end]
        # print(title)
        img_head = '<center><img src="'
        img_start = web_page.find(img_head)
        if img_start is not -1:
          img_tail = '"'
          img_end = web_page.find(img_tail, img_start + len(img_head))
          if img_end is not -1:
            img_file = web_page[img_start + len(img_head):img_end]
            # print(img_file, title)
            parts = img_file.split("-")
            patent_name = parts[0]

            last_slash = file_name.rfind("/")
            img_path = file_name[:last_slash] + "/" + img_file

            # print(img_path)
            img = mpimg.imread(img_path)

            mean = np.mean(img)
            # print(mean)
            if mean < 200:
              continue

            if len(img.shape) == 3:
              height, width, chan = img.shape
              img = img[:,:,0:1].reshape(height, width)

            # print(img.shape)
            # plt.figure(figsize = (5, 5))
            # plt.axis('off')
            # imgplot = plt.imshow(img, "gray")
            # plt.show()
            # print()

            height, width = img.shape
            minvals = np.amin(img, axis=0)

            num_blank_stripes = 0
            was_255 = True

            split_start = 0
            split_end = 0

            if width > height:
              resized = cv2.resize(img, (target_size, target_size*height//width), interpolation=cv2.INTER_CUBIC)
            elif height > width:
              resized = cv2.resize(img, (target_size*width//height, target_size), interpolation=cv2.INTER_CUBIC )
            else:
              resized = cv2.resize(img, (target_size, target_size), interpolation=cv2.INTER_CUBIC)

            height, width = resized.shape
            result = np.full((target_size, target_size), (255), dtype=np.uint8)
            xx = (target_size - width) // 2
            yy = (target_size - height) // 2
            result[yy:yy+height, xx:xx+width] = resized

            # print(width, height)

            class_head = "U.S. Cl. </b><b>"
            class_start = web_page.find(class_head)
            if class_start is not -1:
              class_tail = "</b>"
              class_end = web_page.find(class_tail, class_start + len(class_head))
              class_text = web_page[class_start + len(class_head):class_end]
              # print(class_text)
              class_parts = class_text.split("&#x2014;")
              if len(class_parts) is 1:
                class_parts = class_text.split("&#8212;")
              if len(class_parts) is 2:
                class_text = class_parts[0].replace(" ", "") + "-" + class_parts[1]

                cv2.imwrite("design_patent_images_2007/" + patent_name + ".png", result)
                metadata_text = patent_name + "\t" + class_text + "\t" + title
                print(metadata_text)
                metadata_file.write(metadata_text + "\n")

                # plt.figure(figsize = (5, 5))
                # plt.axis('off')
                # imgplot = plt.imshow(result, "gray")
                # plt.show()
                # print()

metadata_file.close()
# Out:
# USD0534331	D1-121	Pet chew
# USD0534332	D2-95	Outsole for a shoe
# USD0534333	D2-606	Bow tie with biblical phrases and musical notes
# USD0534334	D2-743	Hospital garment
# USD0534335	D2-836	Portion of a garment
# USD0534336	D2-840	Shirt
# USD0534338	D2-969	Footwear upper
# USD0534339	D2-969	Footwear upper
# USD0534340	D2-969	Footwear upper
# USD0534341	D2-971	Shoe
# USD0534342	D2-972	Portion of a shoe upper
# USD0534343	D2-972	Portion of a shoe upper
# USD0534344	D2-977	Blind shoe seam design
# USD0534345	D2-977	Portion of a shoe midsole
# USD0534346	D2-977	Portion of a shoe midsole
# USD0534347	D3-238	Bag
# USD0534348	D3-243	Handbag
# USD0534349	D3-243	Handbag
# USD0534350	D3-243	Handbag
# USD0534352	D3-246	Handbag
# USD0534353	D3-279	Luggage
# USD0534354	D3-319	Modular tool storage drawer
# USD0534355	D3-320	Golf bag club divider
# USD0534356	D3-321	Portion of a tote bag
# USD0534357	D5-47	Fabric construction
# USD0534359	D6-309	Oval mirror
# USD0534360	D6-312	Picture frame
# USD0534361	D6-323	Hanger with air freshener therein
# USD0534362	D6-333	Child safety seat
# USD0534363	D6-335	Modular three piece L-shaped seating set
# USD0534364	D6-366	Seating unit having armrests
# USD0534365	D6-366	Chair
# USD0534366	D6-375	Armchair
# USD0534367	D6-390	Bassinet
# USD0534368	D6-396	Refreshment stand for swimming pools
# USD0534369	D6-396	Display apparatus
# USD0534370	D6-446	Vanity cabinet
# USD0534371	D6-446	Dresser
# USD0534372	D6-457	Eyewear display
# USD0534373	D6-457	Display rack
# USD0534374	D6-465	Vertical clothes holder
# USD0534375	D6-465	Floor spinner rack
# USD0534376	D6-468	Display rack
# USD0534377	D6-484	Table
# USD0534378	D6-484	Table
# USD0534379	D6-484	Furniture unit
# USD0534380	D6-488	Table
# USD0534381	D6-495	Exposed legs for a play yard
# USD0534382	D6-499	Support base
# USD0534383	D6-501	Chair
# USD0534385	D6-502	Chair
# USD0534386	D6-511	Conference table top
# USD0534387	D6-518	Tissue box
# USD0534388	D6-574	Shelving
# USD0534389	D6-601	Travel pillow
# USD0534390	D7-318	Insulated container
# USD0534391	D7-330	Toaster
# USD0534392	D7-330	Cream toaster
# USD0534393	D7-376	Blender insert for a food shaker
# USD0534394	D7-378	Blender
# USD0534395	D7-409	Barbecue grill with collector pan
# USD0534396	D7-532	Mug
# USD0534397	D7-620	Cupholder for slidable interaction with a hollow armrest
# USD0534398	D7-653	Spoon
# USD0534399	D7-653	Spoon
# USD0534400	D7-665	Juice extractor appliance
# USD0534401	D8-20	Saw blade
# USD0534402	D8-49	Powered staple gun
# USD0534403	D8-68	Drill
# USD0534404	D8-68	Cordless drill
# USD0534405	D8-68	Cordless drill
# USD0534406	D8-68	Electric handtool
# USD0534407	D8-69	Hammer drill non-spindle lock
# USD0534409	D8-78	Hammerhead
# USD0534410	D8-80	Tool handle cover
# USD0534411	D8-107	Handle for power bander
# USD0534412	D8-107	Tool handles
# USD0534413	D8-303	Grip
# USD0534414	D8-347	Electronic key
# USD0534415	D8-349	Housing for a pin switch or decelerator for furniture or the like
# USD0534416	D8-356	Gear shaped carabiner
# USD0534417	D8-382	Cable connector
# USD0534418	D8-396	Re-bar clamp
# USD0534419	D9-418	Package with a transparent window
# USD0534420	D9-420	Single compartment hinged container
# USD0534421	D9-420	Container
# USD0534422	D9-422	Container with rotating lid
# USD0534423	D9-426	Container
# USD0534424	D9-430	Container
# USD0534425	D9-448	Pump dispenser
# USD0534426	D9-449	Cosmetic container
# USD0534427	D9-453	Closure
# USD0534428	D9-516	Container shoulder
# USD0534429	D9-516	Container dome
# USD0534430	D9-519	Container
# USD0534431	D9-531	Beverage bottle
# USD0534432	D9-552	Bottle
# USD0534433	D9-723	Propel/repel dispensing container
# USD0534434	D9-724	Product dispensing package
# USD0534435	D9-729	Propel/repel dispensing container
# USD0534436	D9-756	Array of product dispensers
# USD0534439	D10-40	Adjustable timer housing
# USD0534440	D10-40	Timer
# USD0534441	D10-40	Timer
# USD0534442	D10-40	Adjustable timer housing
# USD0534443	D10-50	Construction thermostat
# USD0534444	D10-78	Hand-held diagnostic instrument
# USD0534445	D10-78	Handheld diagnostic instrument
# USD0534446	D10-81	Handheld instrument
# USD0534447	D10-86	Tire pump
# USD0534448	D10-104	Authentication device
# USD0534449	D10-116	Fishing pole alarm
# USD0534450	D10-132	Case for a wristwatch
# USD0534451	D11-1	Heart shaped jewelry
# USD0534452	D11-1	Heart shaped jewelry
# USD0534453	D11-3	Decorative waistlet
# USD0534454	D11-34	Ring
# USD0534455	D11-79	Circular key chain
# USD0534456	D11-157	Star recognition award
# USD0534457	D11-160	Decorative article
# USD0534458	D12-91	Automobile body
# USD0534459	D12-91	Automobile body
# USD0534460	D12-124	Bicycle derailleur
# USD0534461	D12-163	Vehicle grille
# USD0534462	D12-169	Rear bumper for an automobile
# USD0534463	D12-169	Bumper for automobiles
# USD0534464	D12-169	Vehicle rear bumper
# USD0534465	D12-176	Front face of a steering wheel
# USD0534466	D12-182	Motorcycle fairing
# USD0534467	D12-192	Surface configuration of a dashboard for a vehicle
# USD0534468	D12-192	Truck system dashboard
# USD0534469	D12-194	Surface configuration of an exhaust pipe for a vehicle
# USD0534470	D12-195	Door lining for automobile
# USD0534471	D12-203	Vehicle step garnish
# USD0534472	D12-205	Wheel rim
# USD0534473	D12-211	Wheel for a motor vehicle
# USD0534474	D12-211	Front face of a vehicle wheel
# USD0534475	D12-220	Windshield wiper blade cleaner
# USD0534476	D12-400	Decorative kit for vehicles
# USD0534477	D12-400	Decorative kit for vehicles
# USD0534478	D12-400	Decorative kit for vehicles
# USD0534479	D12-400	Decorative kit for vehicles
# USD0534480	D12-419	Folding tray table
# USD0534481	D12-553	Tire tread
# USD0534483	D12-554	Tire tread
# USD0534484	D12-584	Tire tread
# USD0534485	D12-584	Automobile tire
# USD0534486	D12-584	Automobile tire
# USD0534487	D12-588	Tire tread
# USD0534489	D13-108	Charging cradle
# USD0534490	D13-118	Power supply
# USD0534491	D13-119	Removable battery
# USD0534492	D13-123	Optical transmission conversion device
# USD0534493	D13-133	Earphone jack
# USD0534494	D13-133	Audio jack connector
# USD0534495	D13-139.4	Interconnect enclosure for computer and audio visual equipment concealable in a table top
# USD0534496	D13-139.8	Electrical power strip
# USD0534497	D13-146	Electrical coupler
# USD0534498	D13-151	Connector of the temperature sensor for oven range
# USD0534499	D13-156	Lid for the connector of oven range
# USD0534500	D13-158	Switch
# USD0534501	D13-168	Remote control transmitter
# USD0534503	D13-180	Light emitting diode (LED)
# USD0534504	D13-180	Light emitting diode (LED)
# USD0534505	D13-180	Light emitting diode
# USD0534506	D13-182	Electrode layer
# USD0534507	D14-125	Television tuner
# USD0534508	D14-126	Monitor/television receiver
# USD0534509	D14-126	Television set
# USD0534510	D14-128	Projection television
# USD0534511	D14-129	Combined television receiver with digital video disc player and video tape recorder
# USD0534512	D14-130	Video telephone
# USD0534513	D14-132	Transportable DVD multimedia player
# USD0534514	D14-138	Communicator
# USD0534515	D14-138	Mobile phone
# USD0534516	D14-138	Mobile phone
# USD0534517	D14-138	Mobile phone
# USD0534518	D14-138	Portable telephone
# USD0534519	D14-147	Security network handset
# USD0534520	D14-168	Combined radio and CD player
# USD0534521	D14-168	Combined radio and CD player
# USD0534522	D14-168	Combined radio, tape and CD player
# USD0534523	D14-214	Sub woofer
# USD0534524	D14-214	Speaker box
# USD0534525	D14-216	Speaker
# USD0534526	D14-225	Microphone
# USD0534527	D14-230	Combine antenna
# USD0534528	D14-232	Car antenna
# USD0534529	D14-234	Antenna
# USD0534530	D14-247	Key button area for a handset
# USD0534531	D14-318	Computer
# USD0534532	D14-366	Disc drive
# USD0534533	D14-391	Keyboard housing
# USD0534534	D14-407	Mouse
# USD0534535	D14-407	Mouse
# USD0534536	D14-408	Mouse
# USD0534537	D14-437	Connecting terminal for chip cards
# USD0534538	D14-486	Iconic display for a display screen of an aircraft flight attendant panel
# USD0534539	D14-486	Iconic display for a display screen of an aircraft flight attendant panel
# USD0534540	D14-486	Iconic display for a display screen of an aircraft flight attendant panel
# USD0534541	D14-486	User interface icon for a portion of a display screen
# USD0534542	D14-487	Activity indicator for a touch-based user interface for an image processing office machine
# USD0534543	D14-492	Icon for a portion of a display screen
# USD0534545	D14-496	Media device
# USD0534546	D15-4	Outboard motor
# USD0534547	D15-7	Stacked self-priming pump and centrifugal pump
# USD0534548	D15-7	Pump
# USD0534549	D15-9	Air compressor shroud
# USD0534550	D15-9	Air compressor shroud
# USD0534551	D15-19	Mortar mixer
# USD0534552	D15-25	Hydraulic excavator
# USD0534553	D15-81	Juice chiller
# USD0534554	D15-85	Refrigerator
# USD0534555	D15-85	Refrigerator
# USD0534556	D15-85	Refrigerator
# USD0534557	D15-124	Blast cabinet
# USD0534558	D15-140	Tool-holding adapter
# USD0534559	D15-143	Magnet and bearing stack
# USD0534560	D15-143	Linear actuator
# USD0534561	D15-150	Oil bath
# USD0534562	D15-199	Extruder plate for diamond shaped extruder insert
# USD0534563	D16-135	Handle for a magnifier
# USD0534564	D16-202	Digital camera
# USD0534565	D16-202	Video camera
# USD0534566	D16-208	Combined video camera and disc recorder
# USD0534567	D16-309	Fabric-wrapped sunglasses with attached sun hat
# USD0534568	D16-314	Safety eyewear
# USD0534569	D16-315	Eyeglass frame
# USD0534570	D16-315	Eyeglasses
# USD0534571	D16-326	Eyeglasses
# USD0534572	D16-326	Eyeglasses
# USD0534573	D16-326	Sunglass
# USD0534574	D16-329	Eyeglasses
# USD0534575	D17-22	Adjusting bolt seat for a drum
# USD0534576	D18-43	Toner cartridge
# USD0534577	D18-50	Printer
# USD0534578	D18-55	Printer
# USD0534579	D18-55	Printer
# USD0534580	D18-56	Ink stick for phase change ink jet printer
# USD0534581	D18-56	Ink cartridge
# USD0534582	D18-56	Ink cartridge for printer
# USD0534583	D19-3	Ballot envelope
# USD0534584	D19-34	Imaged elastic bookmark
# USD0534585	D19-44	Pen
# USD0534586	D19-50	Ballpoint pen
# USD0534587	D19-57	Cap for a writing instrument
# USD0534588	D19-65	Rectangular clip
# USD0534589	D19-69	Tape dispenser
# USD0534590	D21-385	Gaming system dome cap for a shared symbol display cap
# USD0534591	D21-432	Electrical sand motorcycle for kids
# USD0534592	D21-549	Toy vehicle
# USD0534594	D21-620	Plush toy animal
# USD0534595	D21-747	Iron golf club head
# USD0534596	D21-747	Iron golf club head
# USD0534597	D21-749	Golf iron head
# USD0534598	D21-752	Golf club head
# USD0534599	D21-752	Golf club head
# USD0534600	D21-752	Golf club head
# USD0534601	D21-754	Golf club head cover
# USD0534602	D21-756	Golf grip
# USD0534603	D21-756	Golf grip
# USD0534604	D21-756	Golf grip
# USD0534605	D21-756	Golf grip
# USD0534606	D21-756	Golf grip
# USD0534607	D21-756	Golf grip
# USD0534608	D21-759	Head for golf club
# USD0534609	D21-759	Golf club cavity
# USD0534610	D21-782	Cue stick holder
# USD0534611	D21-810	Towable diving plane
# USD0534612	D21-823	Seat
# USD0534613	D21-823	Seat
# USD0534614	D21-834	Tent with ridge pole
# USD0534615	D21-834	Tent
# USD0534616	D22-143	Line guide for fishing rod
# USD0534617	D23-223	Battery operated airbrush
# USD0534618	D23-223	Handheld shower
# USD0534619	D23-238	Faucet
# USD0534620	D23-238	Faucet
# USD0534621	D23-238	Faucet
# USD0534622	D23-238	Faucet
# USD0534623	D23-238	Faucet
# USD0534624	D23-238	Faucet
# USD0534625	D23-255	Spout
# USD0534626	D23-286	Folding sink
# USD0534627	D23-314	Heating apparatus
# USD0534628	D23-324	Control panel for automobile air-conditioning systems
# USD0534629	D23-335	Heater supported by a rotatable stand
# USD0534630	D23-351	Air conditioner
# USD0534631	D23-351	Air conditioner
# USD0534632	D23-351	Air conditioner
# USD0534636	D23-351	Air conditioner
# USD0534638	D23-353	Air conditioner
# USD0534639	D23-364	Air purifier
# USD0534640	D23-366	Volatile actives dispenser
# USD0534641	D23-366	Aroma dispensing devices
# USD0534642	D23-366	Diffusion evaporator for active substances
# USD0534643	D23-370	Window fan
# USD0534644	D23-411	Blade arm for a ceiling fan
# USD0534645	D23-411	Air guide
# USD0534646	D24-101	Nutritional supplement tablet
# USD0534647	D24-110.6	Compression clamp
# USD0534648	D24-115	Dispensing container
# USD0534649	D24-117	Catheter package with collection bag
# USD0534650	D24-133	Handle for a surgical instrument
# USD0534651	D24-133	Powered surgical screwdriver
# USD0534652	D24-135	Laryngoscope blade
# USD0534653	D24-138	Treatment apparatus for endoscope
# USD0534654	D24-138	Processor for endoscope
# USD0534655	D24-138	Light source for medical purposes
# USD0534656	D24-138	Connector for video endoscopes
# USD0534657	D24-220	Tablet crusher
# USD0534658	D24-229	Culture vessel block
# USD0534659	D25-29	Building structure for a carwash
# USD0534660	D25-48	Door facing
# USD0534661	D25-124	Window component extrusion
# USD0534662	D25-135	Column cap assembly
# USD0534663	D25-139	Terra-cotta bardeau facing panel
# USD0534664	D26-2	Metal halide reflector lamp
# USD0534665	D26-2	Light emitting diode lamp
# USD0534666	D26-9	Decorative candle holder
# USD0534668	D26-28	Front combination lamp lens for an automobile
# USD0534669	D26-31	Rear marker light bar
# USD0534670	D26-37	Luminous body
# USD0534671	D26-49	Flashlight body portion
# USD0534672	D26-49	Flashlight body portion
# USD0534673	D26-49	Electric flashlight
# USD0534674	D26-81	Lighting fixture
# USD0534675	D26-81	Light fixture
# USD0534676	D26-87	Wall lamp
# USD0534677	D26-87	Lantern
# USD0534678	D26-87	Wall lamp
# USD0534679	D26-88	Lighting fixture
# USD0534680	D26-135	Lighting fixture center body
# USD0534681	D27-154	Piezoelectric lighter
# USD0534682	D27-183	Cigar holder
# USD0534683	D28-35	Curling iron
# USD0534684	D28-35	Hair iron
# USD0534685	D28-48	Razor handle
# USD0534686	D28-48	Razor handle
# USD0534687	D28-48	Razor handle
# USD0534688	D28-48	Razor handle
# USD0534689	D28-53	Hair clipper
# USD0534690	D28-76	Multi-functional cosmetic compact
# USD0534692	D30-118	Pet bed
# USD0534693	D30-118	Pet bed
# USD0534694	D30-160	Toy for animals
# USD0534695	D30-161	Litter pan
# USD0534696	D32-1	Cleaner
# USD0534697	D32-21	Vacuum system
# USD0534698	D32-30	Container for a spray lance
# USD0534699	D32-31	Portion of a portable cleaning machine
# USD0534700	D32-55	Sponge holder
# USD0534701	D32-55	Expandable dish rack
# USD0534702	D34-9	Trash can
# USD0534703	D34-28	Movable container
# USD0534704	D34-33	Object lifting device
# USD0534705	D99-28	Automated teller machine

# %%
# !zip -r design_patent_images_2007.zip design_patent_images_2007
